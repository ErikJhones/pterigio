# %% [markdown]
# # Imports

# %%
# Bibliotecas para aumentar dataset #####################
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from keras.applications.vgg16 import VGG16 #Biblioteca cnn-vgg16
import numpy as np

#####################  Bibliotecas para separar dados #####################
import cv2 #Trabalhar com imagens
from sklearn.model_selection import train_test_split #Separar dados de treino e teste
from sklearn.utils import shuffle #Embaralhar dados
import os #sistema operacional

# %% [markdown]
# # Função para aumentar o dataset

# %%
def dataAugmentation(path, classe):
    image = load_img(path)
    image = img_to_array(image)
    image = np.expand_dims(image, axis=0)
    # contruindo o gerador de imagem para data augmentation
    aug = ImageDataGenerator(
        rotation_range=30,
        zoom_range=0.15,
        #width_shift_range=0.2,
        #height_shift_range=0.2,
        shear_range=0.15,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode="nearest")
    
    total = 0
    saveDir = ''
    #local de destino das imagens
    if(classe == 0):
        saveDir = 'C:/Users/David/PycharmProjects/CNN-Pterygium/Aug/NewG0/'
    elif(classe == 1):
        saveDir = 'C:/Users/David/PycharmProjects/CNN-Pterygium/Aug/NewG1/'
    elif(classe == 2):
        saveDir = 'C:/Users/David/PycharmProjects/CNN-Pterygium/Aug/NewG2/'
    elif(classe == 3):
        saveDir = 'C:/Users/David/PycharmProjects/CNN-Pterygium/Aug/NewG3/'
    elif(classe == 4):
        saveDir = 'C:/Users/David/PycharmProjects/CNN-Pterygium/Aug/NewG4/'
        
    imageGen = aug.flow(image, batch_size=1, save_to_dir=saveDir,
            save_prefix="image", save_format="jpg")
    # loop que faz o controle do número de imagens a serem geradas (no caso 100)
    for image in imageGen:
        total += 1
        if total == 8:
            break

# %% [markdown]
# # Data augmentation

# %%
path = 'C:/Users/David/PycharmProjects/CNN-Pterygium/GrausPt/'

for caminho, d, file in os.walk(path):
    for filename in file:
        img = cv2.imread(os.path.join(caminho,filename))

        if caminho == 'C:/Users/David/PycharmProjects/CNN-Pterygium/GrausPt/g0':
            cv2.imwrite('C:/Users/David/PycharmProjects/CNN-Pterygium/Aug/NewG0/'+filename, img)
            dataAugmentation(os.path.join(caminho,filename), 0)
       
        elif caminho == 'C:/Users/David/PycharmProjects/CNN-Pterygium/GrausPt/g1':
            cv2.imwrite('C:/Users/David/PycharmProjects/CNN-Pterygium/Aug/NewG1/'+filename, img)
            dataAugmentation(os.path.join(caminho,filename), 1)
          
        elif caminho == 'C:/Users/David/PycharmProjects/CNN-Pterygium/GrausPt/g2':
            cv2.imwrite('C:/Users/David/PycharmProjects/CNN-Pterygium/Aug/NewG2/'+filename, img)
            dataAugmentation(os.path.join(caminho,filename), 2)
            
        elif caminho == 'C:/Users/David/PycharmProjects/CNN-Pterygium/GrausPt/g3':
            cv2.imwrite('C:/Users/David/PycharmProjects/CNN-Pterygium/Aug/NewG3/'+filename, img)
            dataAugmentation(os.path.join(caminho,filename), 3)
        
        elif caminho == 'C:/Users/David/PycharmProjects/CNN-Pterygium/GrausPt/g4':
            cv2.imwrite('C:/Users/David/PycharmProjects/CNN-Pterygium/Aug/NewG4/'+filename, img)
            dataAugmentation(os.path.join(caminho,filename), 4)

# %%
path = 'C:/Users/David/PycharmProjects/CNN-Pterygium/Aug/'
data_set = []
saidas = []
        
for caminho, d, file in os.walk(path):
    for filename in file:
        
        img = cv2.imread(os.path.join(caminho,filename))
        
        #gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) #Deixa a imagem com tons de cinza
        #equalized_image = cv2.equalizeHist(gray) #Aumentar o contraste da imagem
        #img2 = np.array(cv2.resize(gray, (224,224), interpolation = cv2.INTER_AREA))
        data_set.append(img)
        
        if caminho == 'C:/Users/David/PycharmProjects/CNN-Pterygium/Aug/NewG0':
            saidas.append(0)
        elif caminho == 'C:/Users/David/PycharmProjects/CNN-Pterygium/Aug/NewG1':
            saidas.append(1)
        elif caminho == 'C:/Users/David/PycharmProjects/CNN-Pterygium/Aug/NewG2':
            saidas.append(2)
        elif caminho == 'C:/Users/David/PycharmProjects/CNN-Pterygium/Aug/NewG3':
            saidas.append(3)
        elif caminho == 'C:/Users/David/PycharmProjects/CNN-Pterygium/Aug/NewG4':
            saidas.append(4)

# %%
len(saidas), len(data_set)
# Out:
# (3348, 3348)

# %%
X, Y = shuffle(data_set, saidas) #embaralha os dados

train_X = []
train_Y = []

test_X = []
test_Y = []

train_X, test_X, train_Y, test_Y = train_test_split(X, Y, train_size=0.8, random_state=42) #separa os dados em treino e teste com porcentagen de 80% para treino

#Deixando no mesmo tipo do array do data_set
train_Y = np.array(train_Y).astype('uint8')
test_Y = np.array(test_Y).astype('uint8')

train_X = np.array(train_X)
test_X = np.array(test_X)

# %%
from keras.utils import to_categorical
import matplotlib.pyplot as plt
# %matplotlib inline

print('Tamanho e quantidade da base de dados de treino:', train_X.shape, train_Y.shape)

print('Tamanho e quantidade da base de dados de teste:', test_X.shape, test_Y.shape)
# Out:
# Tamanho e quantidade da base de dados de treino: (2678, 128, 128, 3) (2678,)
# Tamanho e quantidade da base de dados de teste: (670, 128, 128, 3) (670,)

# %%
# Encontra o numero de classes
classes = np.unique(train_Y) #Pega o valores sem repetição
nClasses = len(classes)
print('Numero total de classes:', nClasses)
print('Saida das classes:', classes)
# Out:
# Numero total de classes: 5
# Saida das classes: [0 1 2 3 4]

# %%
plt.figure(figsize=[5,5])

#Mostra a primeira imagem dos dados de treino

plt.subplot(121)
plt.imshow(train_X[0,:,:], cmap='gray')
plt.title("Classe : {}".format(train_Y[0]))

#Mostra a primeira imagem dos dados de teste
plt.subplot(122)
plt.imshow(test_X[5,:,:], cmap='gray')
plt.title("Classe : {}".format(test_Y[5]))
# Out:
# Text(0.5, 1.0, 'Classe : 4')

# %%
# Deixar as imagens na mesma dimensão
train_X = train_X.reshape(-1, 128, 128, 3)
test_X = test_X.reshape(-1, 128, 128, 3)
train_X.shape, test_X.shape
# Out:
# ((2678, 128, 128, 3), (670, 128, 128, 3))

# %%
#Normalizando a imagens deixando os pixels entre 0 e 1
train_X = train_X.astype('float32')
test_X = test_X.astype('float32')
train_X = train_X / 255.
test_X = test_X / 255.

# %%
# Mudança de codificação de código de classe para se padronizar com o Keras.
train_Y_one_hot = to_categorical(train_Y)
test_Y_one_hot = to_categorical(test_Y)

# Testando a padronização de rotulo
print('Rotulo Original:', train_Y[0])
print('Depois da conversão para o one-hot:', train_Y_one_hot[0])
# Out:
# Rotulo Original: 3
# Depois da conversão para o one-hot: [0. 0. 0. 1. 0.]

# %%
#Validação do modelo
from sklearn.model_selection import train_test_split
train_X,valid_X,train_label,valid_label = train_test_split(train_X, train_Y_one_hot, test_size=0.2, random_state=13)

# %%
train_X[0].shape, valid_X.shape, train_label.shape, valid_label.shape
# Out:
# ((128, 128, 3), (536, 128, 128, 3), (2142, 5), (536, 5))

# %%
#A rede
import keras
from keras.models import Sequential,Input,Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
from keras.layers.advanced_activations import LeakyReLU
from keras.optimizers import SGD

# %%
batch_size = 64 #Quantidade de neuronios que seram utilizados.
epochs = 10 #Interações
num_classes = 5

# %%
vgg = keras.applications.VGG16(input_shape=(128,128,3), include_top = False, weights= 'imagenet')

# %%
x = vgg.output
x = Flatten()(x)
x = Dense(3078,activation='relu')(x) 
x = Dropout(0.5)(x)
x = Dense(256,activation='relu')(x) 
x = Dropout(0.2)(x)
out = Dense(5,activation='softmax')(x)
tf_model=Model(inputs=vgg.input,outputs=out)
for layer in tf_model.layers[:20]:
    layer.trainable=False

# %%
tf_model.compile(optimizer=keras.optimizers.Adam(), loss = keras.losses.categorical_crossentropy, metrics=['accuracy'])

# %%
train_label.shape
# Out:
# (2142, 5)

# %%
history = tf_model.fit(train_X, train_label, batch_size = 64, epochs = 60, initial_epoch = 0, validation_data = (valid_X, valid_label))
# Out:
# Train on 2142 samples, validate on 536 samples
# Epoch 1/60
# 2142/2142 [==============================] - 13s 6ms/step - loss: 1.9431 - accuracy: 0.4174 - val_loss: 1.2544 - val_accuracy: 0.5093
# Epoch 2/60
# 2142/2142 [==============================] - 11s 5ms/step - loss: 1.2053 - accuracy: 0.5187 - val_loss: 1.0296 - val_accuracy: 0.5802
# Epoch 3/60
# 2142/2142 [==============================] - 11s 5ms/step - loss: 1.0425 - accuracy: 0.5780 - val_loss: 0.9048 - val_accuracy: 0.6381
# Epoch 4/60
# 2142/2142 [==============================] - 11s 5ms/step - loss: 0.8989 - accuracy: 0.6340 - val_loss: 0.8355 - val_accuracy: 0.6567
# Epoch 5/60
# 2142/2142 [==============================] - 10s 5ms/step - loss: 0.7970 - accuracy: 0.7026 - val_loss: 0.7396 - val_accuracy: 0.7034
# Epoch 6/60
# 2142/2142 [==============================] - 10s 5ms/step - loss: 0.7173 - accuracy: 0.7199 - val_loss: 0.6830 - val_accuracy: 0.7127
# Epoch 7/60
# 2142/2142 [==============================] - 11s 5ms/step - loss: 0.6412 - accuracy: 0.7404 - val_loss: 0.6995 - val_accuracy: 0.7201
# Epoch 8/60
# 2142/2142 [==============================] - 11s 5ms/step - loss: 0.5512 - accuracy: 0.7876 - val_loss: 0.6347 - val_accuracy: 0.7369
# Epoch 9/60
# 2142/2142 [==============================] - 11s 5ms/step - loss: 0.5005 - accuracy: 0.8095 - val_loss: 0.5738 - val_accuracy: 0.7612
# Epoch 10/60
# 2142/2142 [==============================] - 10s 5ms/step - loss: 0.4668 - accuracy: 0.8151 - val_loss: 0.6005 - val_accuracy: 0.7463
# Epoch 11/60
# 2142/2142 [==============================] - 9s 4ms/step - loss: 0.4382 - accuracy: 0.8268 - val_loss: 0.6674 - val_accuracy: 0.7201
# Epoch 12/60
# 2142/2142 [==============================] - 10s 5ms/step - loss: 0.4023 - accuracy: 0.8427 - val_loss: 0.6922 - val_accuracy: 0.7407
# Epoch 13/60
# 2142/2142 [==============================] - 9s 4ms/step - loss: 0.3924 - accuracy: 0.8441 - val_loss: 0.6133 - val_accuracy: 0.7649
# Epoch 14/60
# 2142/2142 [==============================] - 8s 4ms/step - loss: 0.3589 - accuracy: 0.8651 - val_loss: 0.6403 - val_accuracy: 0.7481
# Epoch 15/60
# 2142/2142 [==============================] - 9s 4ms/step - loss: 0.3360 - accuracy: 0.8744 - val_loss: 0.5474 - val_accuracy: 0.7854
# Epoch 16/60
# 2142/2142 [==============================] - 9s 4ms/step - loss: 0.2997 - accuracy: 0.8824 - val_loss: 0.6185 - val_accuracy: 0.7481
# Epoch 17/60
# 2142/2142 [==============================] - 10s 5ms/step - loss: 0.2910 - accuracy: 0.8772 - val_loss: 0.6496 - val_accuracy: 0.7761
# Epoch 18/60
# 2142/2142 [==============================] - 7s 3ms/step - loss: 0.2553 - accuracy: 0.8959 - val_loss: 0.5111 - val_accuracy: 0.8190
# Epoch 19/60
# 2142/2142 [==============================] - 7s 3ms/step - loss: 0.2653 - accuracy: 0.8982 - val_loss: 0.5217 - val_accuracy: 0.8134
# Epoch 20/60
# 2142/2142 [==============================] - 11s 5ms/step - loss: 0.2118 - accuracy: 0.9141 - val_loss: 0.6170 - val_accuracy: 0.7966
# Epoch 21/60
# 2142/2142 [==============================] - 12s 5ms/step - loss: 0.1937 - accuracy: 0.9286 - val_loss: 0.5585 - val_accuracy: 0.8116
# Epoch 22/60
# 2142/2142 [==============================] - 7s 3ms/step - loss: 0.2034 - accuracy: 0.9225 - val_loss: 0.5416 - val_accuracy: 0.7948
# Epoch 23/60
# 2142/2142 [==============================] - 6s 3ms/step - loss: 0.1991 - accuracy: 0.9258 - val_loss: 0.6679 - val_accuracy: 0.7854
# Epoch 24/60
# 2142/2142 [==============================] - 7s 3ms/step - loss: 0.1913 - accuracy: 0.9267 - val_loss: 0.5997 - val_accuracy: 0.7836
# Epoch 25/60
# 2142/2142 [==============================] - 6s 3ms/step - loss: 0.2128 - accuracy: 0.9239 - val_loss: 0.5882 - val_accuracy: 0.7985
# Epoch 26/60
# 2142/2142 [==============================] - 7s 3ms/step - loss: 0.1435 - accuracy: 0.9533 - val_loss: 0.5207 - val_accuracy: 0.8116
# Epoch 27/60
# 2142/2142 [==============================] - 7s 3ms/step - loss: 0.1431 - accuracy: 0.9468 - val_loss: 0.6032 - val_accuracy: 0.8228
# Epoch 28/60
# 2142/2142 [==============================] - 9s 4ms/step - loss: 0.1995 - accuracy: 0.9206 - val_loss: 0.6353 - val_accuracy: 0.7799
# Epoch 29/60
# 2142/2142 [==============================] - 9s 4ms/step - loss: 0.1661 - accuracy: 0.9356 - val_loss: 0.6873 - val_accuracy: 0.7966
# Epoch 30/60
# 2142/2142 [==============================] - 6s 3ms/step - loss: 0.1804 - accuracy: 0.9342 - val_loss: 0.6483 - val_accuracy: 0.8060
# Epoch 31/60
# 2142/2142 [==============================] - 6s 3ms/step - loss: 0.1492 - accuracy: 0.9421 - val_loss: 0.5445 - val_accuracy: 0.8116
# Epoch 32/60
# 2142/2142 [==============================] - 6s 3ms/step - loss: 0.1740 - accuracy: 0.9412 - val_loss: 0.5710 - val_accuracy: 0.8209
# Epoch 33/60
# 2142/2142 [==============================] - 6s 3ms/step - loss: 0.1909 - accuracy: 0.9267 - val_loss: 0.5337 - val_accuracy: 0.7929
# Epoch 34/60
# 2142/2142 [==============================] - 6s 3ms/step - loss: 0.1883 - accuracy: 0.9337 - val_loss: 0.7497 - val_accuracy: 0.7929
# Epoch 35/60
# 2142/2142 [==============================] - 7s 3ms/step - loss: 0.1876 - accuracy: 0.9318 - val_loss: 0.5120 - val_accuracy: 0.8284
# Epoch 36/60
# 2142/2142 [==============================] - 6s 3ms/step - loss: 0.1614 - accuracy: 0.9454 - val_loss: 0.8079 - val_accuracy: 0.7910
# Epoch 37/60
# 2142/2142 [==============================] - 6s 3ms/step - loss: 0.1623 - accuracy: 0.9407 - val_loss: 0.7879 - val_accuracy: 0.7836
# Epoch 38/60
# 2142/2142 [==============================] - 6s 3ms/step - loss: 0.1660 - accuracy: 0.9379 - val_loss: 0.5312 - val_accuracy: 0.8246
# Epoch 39/60
# 2142/2142 [==============================] - 6s 3ms/step - loss: 0.1365 - accuracy: 0.9505 - val_loss: 0.5451 - val_accuracy: 0.8284
# Epoch 40/60
# 2142/2142 [==============================] - 6s 3ms/step - loss: 0.1362 - accuracy: 0.9514 - val_loss: 0.5140 - val_accuracy: 0.8265
# Epoch 41/60
# 2142/2142 [==============================] - 6s 3ms/step - loss: 0.1357 - accuracy: 0.9510 - val_loss: 0.5509 - val_accuracy: 0.8172
# Epoch 42/60
# 2142/2142 [==============================] - 8s 4ms/step - loss: 0.1272 - accuracy: 0.9552 - val_loss: 0.5675 - val_accuracy: 0.8340
# Epoch 43/60
# 2142/2142 [==============================] - 10s 5ms/step - loss: 0.1417 - accuracy: 0.9468 - val_loss: 0.4925 - val_accuracy: 0.8284
# Epoch 44/60
# 2142/2142 [==============================] - 8s 4ms/step - loss: 0.1765 - accuracy: 0.9314 - val_loss: 0.4741 - val_accuracy: 0.8507
# Epoch 45/60
# 2142/2142 [==============================] - 8s 4ms/step - loss: 0.1393 - accuracy: 0.9486 - val_loss: 0.4607 - val_accuracy: 0.8433
# Epoch 46/60
# 2142/2142 [==============================] - 6s 3ms/step - loss: 0.1264 - accuracy: 0.9552 - val_loss: 0.5457 - val_accuracy: 0.8340
# Epoch 47/60
# 2142/2142 [==============================] - 8s 4ms/step - loss: 0.1068 - accuracy: 0.9589 - val_loss: 0.4748 - val_accuracy: 0.8470
# Epoch 48/60
# 2142/2142 [==============================] - 8s 4ms/step - loss: 0.1119 - accuracy: 0.9575 - val_loss: 0.6993 - val_accuracy: 0.8060
# Epoch 49/60
# 2142/2142 [==============================] - 6s 3ms/step - loss: 0.1107 - accuracy: 0.9599 - val_loss: 0.6116 - val_accuracy: 0.8265
# Epoch 50/60
# 2142/2142 [==============================] - 11s 5ms/step - loss: 0.1149 - accuracy: 0.9599 - val_loss: 0.5749 - val_accuracy: 0.8284
# Epoch 51/60
# 2142/2142 [==============================] - 7s 3ms/step - loss: 0.1260 - accuracy: 0.9561 - val_loss: 0.5028 - val_accuracy: 0.8190
# Epoch 52/60
# 2142/2142 [==============================] - 7s 3ms/step - loss: 0.0988 - accuracy: 0.9687 - val_loss: 0.5141 - val_accuracy: 0.8302
# Epoch 53/60
# 2142/2142 [==============================] - 7s 3ms/step - loss: 0.0891 - accuracy: 0.9687 - val_loss: 0.5515 - val_accuracy: 0.8358
# Epoch 54/60
# 2142/2142 [==============================] - 6s 3ms/step - loss: 0.1015 - accuracy: 0.9659 - val_loss: 0.5056 - val_accuracy: 0.8433
# Epoch 55/60
# 2142/2142 [==============================] - 8s 4ms/step - loss: 0.1509 - accuracy: 0.9398 - val_loss: 0.4764 - val_accuracy: 0.8414
# Epoch 56/60
# 2142/2142 [==============================] - 9s 4ms/step - loss: 0.1546 - accuracy: 0.9458 - val_loss: 0.4852 - val_accuracy: 0.8134
# Epoch 57/60
# 2142/2142 [==============================] - 11s 5ms/step - loss: 0.1201 - accuracy: 0.9528 - val_loss: 0.4682 - val_accuracy: 0.8302
# Epoch 58/60
# 2142/2142 [==============================] - 17s 8ms/step - loss: 0.1181 - accuracy: 0.9570 - val_loss: 0.5957 - val_accuracy: 0.8302
# Epoch 59/60
# 2142/2142 [==============================] - 6s 3ms/step - loss: 0.1012 - accuracy: 0.9678 - val_loss: 0.6594 - val_accuracy: 0.8004
# Epoch 60/60
# 2142/2142 [==============================] - 6s 3ms/step - loss: 0.1493 - accuracy: 0.9444 - val_loss: 0.5676 - val_accuracy: 0.8396

# %%
#Salvando treinamento
tf_model.save("fashion_model_dropout.h5py")

# %%
#Validação da parte de teste
test_eval = tf_model.evaluate(test_X, test_Y_one_hot, verbose=1)
# Out:
# 670/670 [==============================] - 1s 2ms/step

# %%
#Plotando graficos referentes a treinamento e validação acurácia e loss
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(accuracy))

plt.plot(epochs, accuracy, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
#Predizendo a  classe a partir da base de teste_X
predicted_classes = tf_model.predict(test_X)
predicted_classes = np.argmax(np.round(predicted_classes),axis=1)
predicted_classes.shape, test_Y.shape
# Out:
# ((670,), (670,))

# %%
correct = np.where(predicted_classes==test_Y)[0]

# %%
#Mostrando a quantidade de acertos e alguns exemplos
correct = np.where(predicted_classes==test_Y)[0]
print ("Found %d correct labels" % len(correct))
for i, correct in enumerate(correct[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(test_X[correct].reshape(128,128,3), cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(predicted_classes[correct], test_Y[correct]))
    plt.tight_layout()
# Out:
# Found 548 correct labels

# %%
#Mostrando a quantidade de erros e alguns exemplos
incorrect = np.where(predicted_classes!=test_Y)[0]
print ("Found %d incorrect labels" % len(incorrect))
for i, incorrect in enumerate(incorrect[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(test_X[incorrect].reshape(128,128,3), cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(predicted_classes[incorrect], test_Y[incorrect]))
    plt.tight_layout()
# Out:
# Found 122 incorrect labels

# %%
#Precisão de classificação
from sklearn.metrics import classification_report
target_names = ["Class {}".format(i) for i in range(num_classes)]
print(classification_report(test_Y, predicted_classes, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.71      0.90      0.79        40
#      Class 1       0.85      0.88      0.87        33
#      Class 2       0.75      0.64      0.69        77
#      Class 3       0.83      0.92      0.88       359
#      Class 4       0.84      0.63      0.72       161
#
#     accuracy                           0.82       670
#    macro avg       0.80      0.79      0.79       670
# weighted avg       0.82      0.82      0.81       670

# %%
fashion_model = Sequential()

fashion_model.add(Conv2D(16, kernel_size=(3, 3),activation='relu',padding='same',input_shape=(128,128,3)))
fashion_model.add(LeakyReLU(alpha=0.1))
fashion_model.add(MaxPooling2D((2, 2),padding='same'))
fashion_model.add(Dropout(0.2))

fashion_model.add(Conv2D(32, kernel_size=(3, 3),activation='relu',padding='same'))
fashion_model.add(LeakyReLU(alpha=0.1))
fashion_model.add(MaxPooling2D((2, 2),padding='same'))
fashion_model.add(Dropout(0.25))

fashion_model.add(Conv2D(32, (3, 3), activation='relu',padding='same'))
fashion_model.add(LeakyReLU(alpha=0.01))
fashion_model.add(MaxPooling2D(pool_size=(2, 2),padding='same'))
fashion_model.add(Dropout(0.25))

fashion_model.add(Conv2D(64, (3, 3), activation='relu',padding='same'))
fashion_model.add(LeakyReLU(alpha=0.01))
fashion_model.add(MaxPooling2D(pool_size=(2, 2),padding='same'))
fashion_model.add(Dropout(0.25))

fashion_model.add(Conv2D(64, (3, 3), activation='relu',padding='same'))
fashion_model.add(LeakyReLU(alpha=0.01))                  
fashion_model.add(MaxPooling2D(pool_size=(2, 2),padding='same'))
fashion_model.add(Dropout(0.25))

fashion_model.add(Flatten())
fashion_model.add(Dense(512, activation='sigmoid'))
fashion_model.add(LeakyReLU(alpha=0.01))           
fashion_model.add(Dropout(0.5))
fashion_model.add(Dense(num_classes, activation='softmax'))
sgd = SGD(lr = 0.1, decay=1e-6, momentum=0.9, nesterov=True)

# def conv3x3(input_x,nb_filters):
#     # Prepara a camada convolucional
#     return Conv2D(nb_filters, kernel_size=(3,3), use_bias=False,
#                activation='relu', padding="same")(input_x)

# # Cria o modelo executando um treino e avaliação:
# inputs = Input(shape=(128, 128, 3))
# x = conv3x3(inputs, 32)
# x = conv3x3(x, 32)
# x = MaxPooling2D(pool_size=(2,2))(x) 
# x = conv3x3(x, 64)
# x = conv3x3(x, 64)
# x = MaxPooling2D(pool_size=(2,2))(x) 
# x = conv3x3(x, 128)
# x = MaxPooling2D(pool_size=(2,2))(x) 
# x = Flatten()(x)
# x = Dense(128, activation="relu")(x)
# preds = Dense(4, activation='softmax')(x)
# fashion_model = Model(inputs=inputs, outputs=preds)

# %%
fashion_model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_26 (Conv2D)           (None, 128, 128, 16)      448
# _________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)   (None, 128, 128, 16)      0
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 64, 64, 16)        0
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 64, 64, 32)        4640
# _________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)   (None, 64, 64, 32)        0
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 32, 32, 32)        0
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)   (None, 32, 32, 32)        0
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)   (None, 16, 16, 64)        0
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 8, 8, 64)          36928
# _________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)   (None, 8, 8, 64)          0
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 1024)              0
# _________________________________________________________________
# dense_26 (Dense)             (None, 512)               524800
# _________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)   (None, 512)               0
# _________________________________________________________________
# dropout_46 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 5)                 2565
# =================================================================
# Total params: 597,125
# Trainable params: 597,125
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compilando a rede neural criada usando como metrica a accurancy
fashion_model.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adam(), metrics=['accuracy'])

# %%
#Treinando a rede
fashion_train_dropout = fashion_model.fit(train_X, train_label, batch_size=64,epochs=60,verbose=1,validation_data=(valid_X, valid_label))
# Out:
# Train on 2142 samples, validate on 536 samples
# Epoch 1/60
# 2142/2142 [==============================] - 3s 1ms/step - loss: 1.4593 - accuracy: 0.4146 - val_loss: 1.2795 - val_accuracy: 0.5056
# Epoch 2/60
# 2142/2142 [==============================] - 6s 3ms/step - loss: 1.3082 - accuracy: 0.4967 - val_loss: 1.2064 - val_accuracy: 0.5261
# Epoch 3/60
# 2142/2142 [==============================] - 15s 7ms/step - loss: 1.2269 - accuracy: 0.5145 - val_loss: 1.3858 - val_accuracy: 0.4701
# Epoch 4/60
# 2142/2142 [==============================] - 9s 4ms/step - loss: 1.1936 - accuracy: 0.5476 - val_loss: 1.3512 - val_accuracy: 0.4571
# Epoch 5/60
# 2142/2142 [==============================] - 9s 4ms/step - loss: 1.1549 - accuracy: 0.5439 - val_loss: 1.1246 - val_accuracy: 0.5392
# Epoch 6/60
# 2142/2142 [==============================] - 10s 4ms/step - loss: 1.1600 - accuracy: 0.5439 - val_loss: 1.4167 - val_accuracy: 0.3955
# Epoch 7/60
# 2142/2142 [==============================] - 9s 4ms/step - loss: 1.1295 - accuracy: 0.5476 - val_loss: 1.2417 - val_accuracy: 0.4888
# Epoch 8/60
# 2142/2142 [==============================] - 9s 4ms/step - loss: 1.0975 - accuracy: 0.5528 - val_loss: 1.1410 - val_accuracy: 0.5075
# Epoch 9/60
# 2142/2142 [==============================] - 9s 4ms/step - loss: 1.0629 - accuracy: 0.5565 - val_loss: 1.1944 - val_accuracy: 0.5075
# Epoch 10/60
# 2142/2142 [==============================] - 9s 4ms/step - loss: 1.0661 - accuracy: 0.5630 - val_loss: 1.1787 - val_accuracy: 0.5168
# Epoch 11/60
# 2142/2142 [==============================] - 9s 4ms/step - loss: 1.0436 - accuracy: 0.5686 - val_loss: 1.1250 - val_accuracy: 0.5224
# Epoch 12/60
# 2142/2142 [==============================] - 9s 4ms/step - loss: 1.0052 - accuracy: 0.5710 - val_loss: 1.0711 - val_accuracy: 0.5429
# Epoch 13/60
# 2142/2142 [==============================] - 10s 5ms/step - loss: 0.9761 - accuracy: 0.5906 - val_loss: 1.0690 - val_accuracy: 0.5653
# Epoch 14/60
# 2142/2142 [==============================] - 9s 4ms/step - loss: 0.9666 - accuracy: 0.5896 - val_loss: 1.0637 - val_accuracy: 0.5522
# Epoch 15/60
# 2142/2142 [==============================] - 15s 7ms/step - loss: 0.9731 - accuracy: 0.5831 - val_loss: 1.0187 - val_accuracy: 0.5672
# Epoch 16/60
# 2142/2142 [==============================] - 19s 9ms/step - loss: 0.9145 - accuracy: 0.6190 - val_loss: 1.0323 - val_accuracy: 0.5672
# Epoch 17/60
# 2142/2142 [==============================] - 10s 5ms/step - loss: 0.8798 - accuracy: 0.6284 - val_loss: 0.9329 - val_accuracy: 0.6082
# Epoch 18/60
# 2142/2142 [==============================] - 8s 4ms/step - loss: 0.8506 - accuracy: 0.6485 - val_loss: 0.9971 - val_accuracy: 0.5896
# Epoch 19/60
# 2142/2142 [==============================] - 9s 4ms/step - loss: 0.8213 - accuracy: 0.6555 - val_loss: 0.9833 - val_accuracy: 0.6082
# Epoch 20/60
# 2142/2142 [==============================] - 11s 5ms/step - loss: 0.7805 - accuracy: 0.6839 - val_loss: 0.8743 - val_accuracy: 0.6325
# Epoch 21/60
# 2142/2142 [==============================] - 8s 4ms/step - loss: 0.7473 - accuracy: 0.6933 - val_loss: 0.8777 - val_accuracy: 0.6343
# Epoch 22/60
# 2142/2142 [==============================] - 4s 2ms/step - loss: 0.7243 - accuracy: 0.7021 - val_loss: 0.8426 - val_accuracy: 0.6660
# Epoch 23/60
# 2142/2142 [==============================] - 3s 1ms/step - loss: 0.6993 - accuracy: 0.7152 - val_loss: 0.9492 - val_accuracy: 0.6325
# Epoch 24/60
# 2142/2142 [==============================] - 3s 1ms/step - loss: 0.6939 - accuracy: 0.7218 - val_loss: 0.9094 - val_accuracy: 0.6231
# Epoch 25/60
# 2142/2142 [==============================] - 2s 816us/step - loss: 0.6618 - accuracy: 0.7311 - val_loss: 0.7988 - val_accuracy: 0.6847
# Epoch 26/60
# 2142/2142 [==============================] - 2s 787us/step - loss: 0.6342 - accuracy: 0.7516 - val_loss: 0.8017 - val_accuracy: 0.6903
# Epoch 27/60
# 2142/2142 [==============================] - 2s 799us/step - loss: 0.6062 - accuracy: 0.7493 - val_loss: 0.7635 - val_accuracy: 0.6884
# Epoch 28/60
# 2142/2142 [==============================] - 3s 1ms/step - loss: 0.5833 - accuracy: 0.7563 - val_loss: 0.7692 - val_accuracy: 0.6959
# Epoch 29/60
# 2142/2142 [==============================] - 2s 944us/step - loss: 0.5392 - accuracy: 0.7824 - val_loss: 0.7377 - val_accuracy: 0.6996
# Epoch 30/60
# 2142/2142 [==============================] - 3s 1ms/step - loss: 0.5305 - accuracy: 0.7913 - val_loss: 0.7565 - val_accuracy: 0.7108
# Epoch 31/60
# 2142/2142 [==============================] - 5s 2ms/step - loss: 0.5122 - accuracy: 0.8025 - val_loss: 0.7540 - val_accuracy: 0.7071
# Epoch 32/60
# 2142/2142 [==============================] - 9s 4ms/step - loss: 0.5124 - accuracy: 0.8011 - val_loss: 0.6992 - val_accuracy: 0.6996
# Epoch 33/60
# 2142/2142 [==============================] - 8s 4ms/step - loss: 0.4682 - accuracy: 0.8165 - val_loss: 0.7280 - val_accuracy: 0.7201
# Epoch 34/60
# 2142/2142 [==============================] - 10s 5ms/step - loss: 0.4592 - accuracy: 0.8067 - val_loss: 0.6924 - val_accuracy: 0.7239
# Epoch 35/60
# 2142/2142 [==============================] - 9s 4ms/step - loss: 0.4684 - accuracy: 0.8137 - val_loss: 0.7488 - val_accuracy: 0.7257
# Epoch 36/60
# 2142/2142 [==============================] - 10s 5ms/step - loss: 0.4290 - accuracy: 0.8263 - val_loss: 0.7611 - val_accuracy: 0.7257
# Epoch 37/60
# 2142/2142 [==============================] - 10s 4ms/step - loss: 0.4072 - accuracy: 0.8399 - val_loss: 0.7372 - val_accuracy: 0.7332
# Epoch 38/60
# 2142/2142 [==============================] - 6s 3ms/step - loss: 0.3980 - accuracy: 0.8394 - val_loss: 0.6882 - val_accuracy: 0.7146
# Epoch 39/60
# 2142/2142 [==============================] - 8s 4ms/step - loss: 0.3725 - accuracy: 0.8618 - val_loss: 0.6872 - val_accuracy: 0.7481
# Epoch 40/60
# 2142/2142 [==============================] - 10s 5ms/step - loss: 0.3546 - accuracy: 0.8599 - val_loss: 0.7098 - val_accuracy: 0.7519
# Epoch 41/60
# 2142/2142 [==============================] - 10s 5ms/step - loss: 0.3518 - accuracy: 0.8641 - val_loss: 0.6943 - val_accuracy: 0.7612
# Epoch 42/60
# 2142/2142 [==============================] - 9s 4ms/step - loss: 0.3591 - accuracy: 0.8646 - val_loss: 0.7833 - val_accuracy: 0.7463
# Epoch 43/60
# 2142/2142 [==============================] - 9s 4ms/step - loss: 0.3425 - accuracy: 0.8679 - val_loss: 0.7091 - val_accuracy: 0.7537
# Epoch 44/60
# 2142/2142 [==============================] - 9s 4ms/step - loss: 0.3201 - accuracy: 0.8847 - val_loss: 0.6644 - val_accuracy: 0.7631
# Epoch 45/60
# 2142/2142 [==============================] - 10s 5ms/step - loss: 0.3078 - accuracy: 0.8875 - val_loss: 0.6427 - val_accuracy: 0.7761
# Epoch 46/60
# 2142/2142 [==============================] - 9s 4ms/step - loss: 0.2851 - accuracy: 0.8917 - val_loss: 0.7039 - val_accuracy: 0.7463
# Epoch 47/60
# 2142/2142 [==============================] - 9s 4ms/step - loss: 0.2936 - accuracy: 0.8954 - val_loss: 0.7495 - val_accuracy: 0.7537
# Epoch 48/60
# 2142/2142 [==============================] - 9s 4ms/step - loss: 0.2801 - accuracy: 0.8982 - val_loss: 0.7233 - val_accuracy: 0.7687
# Epoch 49/60
# 2142/2142 [==============================] - 9s 4ms/step - loss: 0.2866 - accuracy: 0.8917 - val_loss: 0.7103 - val_accuracy: 0.7705
# Epoch 50/60
# 2142/2142 [==============================] - 9s 4ms/step - loss: 0.2525 - accuracy: 0.9062 - val_loss: 0.6324 - val_accuracy: 0.7854
# Epoch 51/60
# 2142/2142 [==============================] - 8s 4ms/step - loss: 0.2393 - accuracy: 0.9085 - val_loss: 0.6306 - val_accuracy: 0.7780
# Epoch 52/60
# 2142/2142 [==============================] - 10s 4ms/step - loss: 0.2412 - accuracy: 0.9122 - val_loss: 0.6485 - val_accuracy: 0.7724
# Epoch 53/60
# 2142/2142 [==============================] - 9s 4ms/step - loss: 0.2417 - accuracy: 0.9141 - val_loss: 0.6014 - val_accuracy: 0.7873
# Epoch 54/60
# 2142/2142 [==============================] - 9s 4ms/step - loss: 0.2403 - accuracy: 0.9141 - val_loss: 0.6873 - val_accuracy: 0.7631
# Epoch 55/60
# 2142/2142 [==============================] - 10s 5ms/step - loss: 0.2454 - accuracy: 0.9108 - val_loss: 0.6737 - val_accuracy: 0.7836
# Epoch 56/60
# 2142/2142 [==============================] - 9s 4ms/step - loss: 0.2442 - accuracy: 0.9164 - val_loss: 0.6227 - val_accuracy: 0.7966
# Epoch 57/60
# 2142/2142 [==============================] - 9s 4ms/step - loss: 0.1947 - accuracy: 0.9295 - val_loss: 0.6520 - val_accuracy: 0.8041
# Epoch 58/60
# 2142/2142 [==============================] - 9s 4ms/step - loss: 0.2042 - accuracy: 0.9234 - val_loss: 0.6304 - val_accuracy: 0.7966
# Epoch 59/60
# 2142/2142 [==============================] - 10s 5ms/step - loss: 0.2048 - accuracy: 0.9272 - val_loss: 0.6229 - val_accuracy: 0.7985
# Epoch 60/60
# 2142/2142 [==============================] - 10s 5ms/step - loss: 0.2060 - accuracy: 0.9262 - val_loss: 0.6284 - val_accuracy: 0.8190

# %%
#Salvando treinamento
fashion_model.save("semTransfer.h5py")

# %%
#Validação da parte de teste
test_eval = fashion_model.evaluate(test_X, test_Y_one_hot, verbose=1)
# Out:
# 670/670 [==============================] - 0s 395us/step

# %%
#Plotando graficos referentes a treinamento e validação acurácia e loss
accuracy = fashion_train_dropout.history['accuracy']
val_accuracy = fashion_train_dropout.history['val_accuracy']
loss = fashion_train_dropout.history['loss']
val_loss = fashion_train_dropout.history['val_loss']
epochs = range(len(accuracy))

plt.plot(epochs, accuracy, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
#Predizendo a  classe a partir da base de teste_X
predicted_classes = fashion_model.predict(test_X)
predicted_classes = np.argmax(np.round(predicted_classes),axis=1)
predicted_classes.shape, test_Y.shape
# Out:
# ((670,), (670,))

# %%
#Mostrando a quantidade de acertos e alguns exemplos
correct = np.where(predicted_classes==test_Y)[0]
print ("Found %d correct labels" % len(correct))
for i, correct in enumerate(correct[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(test_X[correct].reshape(128,128,3), cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(predicted_classes[correct], test_Y[correct]))
    plt.tight_layout()
# Out:
# Found 520 correct labels

# %%
#Mostrando a quantidade de erros e alguns exemplos
incorrect = np.where(predicted_classes!=test_Y)[0]
print ("Found %d incorrect labels" % len(incorrect))
for i, incorrect in enumerate(incorrect[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(test_X[incorrect].reshape(128,128,3), cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(predicted_classes[incorrect], test_Y[incorrect]))
    plt.tight_layout()
# Out:
# Found 150 incorrect labels

# %%
#Precisão de classificação
from sklearn.metrics import classification_report
target_names = ["Class {}".format(i) for i in range(num_classes)]
print(classification_report(test_Y, predicted_classes, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.59      0.93      0.72        40
#      Class 1       0.89      0.73      0.80        33
#      Class 2       0.76      0.32      0.45        77
#      Class 3       0.82      0.89      0.85       359
#      Class 4       0.73      0.71      0.72       161
#
#     accuracy                           0.78       670
#    macro avg       0.76      0.72      0.71       670
# weighted avg       0.78      0.78      0.76       670
